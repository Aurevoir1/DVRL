# %%
import tensorflow as tf
import keras

# %%
print('11')
# Out:
# 11

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
len(x_train[:,0])
# Out:
# 50000

# %%
z_train = [[1,2,3,4,5],
          [2,5,6,6,2],
          [6,4,2,6,7],
          [1,4,7,3,2]]

# %%
print(z_train.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 print(z_train.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
len(z_train)
# Out:
# 4

# %%
num_bins = 20

# %%
len(x_train[:,0])/num_bins
# Out:
# 2500.0

# %%
itt = 1

# %%
int(itt * len(x_train[:, 0]) / num_bins)
# Out:
# 2500

# %%
x_train[int(itt * len(x_train[:, 0]) / num_bins):]
# Out:
# array([[[[110, 132,  67],
#          [175, 193, 129],
#          [182, 197, 134],
#          ...,
#          [ 94, 128,  43],
#          [ 99, 134,  54],
#          [ 98, 129,  55]],
#
#         [[127, 148,  86],
#          [119, 138,  76],
#          [133, 149,  88],
#          ...,
#          [ 97, 128,  46],
#          [109, 141,  64],
#          [ 94, 124,  50]],
#
#         [[118, 139,  76],
#          [109, 129,  67],
#          [157, 174, 114],
#          ...,
#          [ 98, 124,  47],
#          [107, 136,  60],
#          [114, 143,  69]],
#
#         ...,
#
#         [[158, 188,  90],
#          [172, 203, 104],
#          [168, 199, 100],
#          ...,
#          [ 32,  38,  46],
#          [ 25,  32,  41],
#          [ 20,  26,  34]],
#
#         [[158, 187,  95],
#          [159, 188,  96],
#          [178, 205, 113],
#          ...,
#          [ 26,  33,  41],
#          [ 26,  33,  42],
#          [ 20,  26,  33]],
#
#         [[148, 180,  88],
# ...

# %%
len()
